# %% [markdown]
# # 中文簡繁統一及 jieba 教學
#
# ## 分詞  &  抓重點詞：TF-IDF

# %%
from opencc import OpenCC
cc = OpenCC('s2tw')
# 保證一定幫你關閉檔案
with open("test.txt", "r", encoding="utf-8") as f:
    to_convert = f.read()
converted = cc.convert(to_convert)
converted
# Out:
# '第2915章 這麼說，師兄是同意了？\n我讓這些蠱仙與你們一起前去，協助搬遷之事，萬一有強敵襲擊，我也能及時知曉，派遣教中強者前去救援。”葛東旭喚出蠱仙大軍之後，說道。\n說罷，葛東旭又交代了龍乙雪等人幾句，然後才打發眾人離去。\n眾人見掌教老爺叫住他們竟然是為了此事，心中自然難免感動。\n眾人離去之後，轉眼間，生死宮便只剩下了楊銀厚和他的三位弟子還有葛東旭。\n東旭，看來你全面收縮地盤，是為了更好地蟄伏，更快地提升我們天丹教的實力，然後再伺機出戰！”楊銀厚沉聲道，雙目精芒電閃。\n沒錯。以我們如今的實力，要想守住手頭的地盤是根本不可能的，既然如此，為什麼不把地盤讓給他們，讓他們去守地盤，如此一來，他們的力量就要分散開來，戰線就要被拉長。哼，我天丹教別的不多，修行資源有的是，地盤暫時讓給他們又有何妨？暫時讓他們得意猖狂又如何？只要在這段時間牟足勁提升實力，等時機成熟了，再時不時派人出去打下秋風，練下兵，然後就撤回禁區，我倒要看看西海龍宮和彌教能有多少兵馬可以源源不斷地投入這流溟道。”葛東旭沉聲道。\n嗤！好一招以退為進，你這手段太狠了，到時恐怕這流溟道會成為他們的絞肉場。”縱然以楊銀厚的老謀深算，聽了葛東旭這一番話，也是忍不住猛吸冷氣。\n絞肉場？”葛東旭搖搖頭，道：“還是太難，因為道主之下，我們的底蘊跟他們相差太大了，任我如何不惜血本，短時間內肯定也難以補上這其中的差距。所以我才想到把所有的地盤讓給他們，把他們的戰線儘量拉長，但這還不夠，除非……”\n說到這裡，葛東旭停頓了下來\n除非什麼？把塞信等人盡數召回來嗎？這也沒用，塞信等人雖然也是一股不小的力量，但跟我們如今擺在明面上的力量一比，其實也算不得什麼，還遠遠不足以影響到大局。”楊銀厚見葛東旭突然停下來，皺了皺眉頭，說道。\n沒錯，塞信那股力量還遠遠不足以影響大局，而且我們真正缺乏的還是道主之下的頂尖力量，所以，除非……”葛東旭說到“除非”兩個字又停了下來。\n除非什麼啊？為兄為此事心急如焚，你就不能把一句話說完嗎？”楊銀厚何等人物，見葛東旭再一次在這兩個字上停下來，哪裡不知道葛東旭這是有意為之，不禁沒好氣地瞪眼道。\n嘿嘿!”葛東旭衝楊銀厚意味深長地笑笑，然後對虎勇三人揮揮手道：“你們也別站在這裡了，該幹什麼幹什麼去。”\n那弟子現在去助蛇姬辦理她族人搬遷之事。”虎勇聞言連忙道。\n嗯，去吧，去吧。慕容你去助鯨猛吧，我來前已經命人去通知坐鎮東海龍宮的妖王，想來他們如今也都已經返回各自山門了。”\n弟子領命！”三人鞠躬領命，只是走前都忍不住有些好奇地看了葛東旭一眼，不知道掌教師叔這“除非”兩個字後面究竟是要講什麼。\n行了，他們已經走了，現在你可以說了。”楊銀厚沒好氣道。\n嘿嘿！”葛東旭笑笑，然後拉過楊銀厚的手，道：“師兄你先坐下，先坐下。”\n看著葛東旭那一臉殷勤的笑容，楊銀厚莫名地渾身起雞皮疙瘩，心裡泛起一絲很不妙的感覺。\n有話快說，有，咳咳，你就別折騰你師兄了。”楊銀厚說道。\n那好吧，我就只問師兄一句話，為了我天丹教，你是不是可以做出任何犧牲？”葛東旭突然臉色一正道。\n這不是廢話嗎？覆巢之下無完卵，天丹教乃是我們在九天界生存的根基，一旦天丹教被毀，我等恐怕無一能倖免。”楊銀厚瞪眼道。\n師兄說的好，我就知道師兄是深明大義之輩！”葛東旭撫掌叫好。\n好什麼好？你總不至於見為兄修的是不死大道就讓為兄一個人去衝鋒陷陣吧？”楊銀厚沒好氣道，心裡越發有一種不妙的感覺。\n一世人兩兄弟，師兄你說這話就太傷師弟我的心了。”葛東旭一臉委屈道。\n好了，好了，東旭，算師兄我求你，你就別跟我拐彎抹角了行不行？”楊銀厚實在有些受不了葛東旭的風格大轉變，轉而對他拱手求道。\n其實也不是什麼難事，就是需要師兄稍微犧牲一下色相，施展一下美男計。”葛東旭說道。\n什麼？”楊銀厚聽到這話眼珠子都瞪圓了，整個人都差點要跳起來。\n這個，師兄你別反應那麼大呀！我聽說上次三危山的青冥特意來拜訪了你，她對你很青睞，很想招攬你。”葛東旭連忙把楊銀厚按回大長老的位置，一臉曖昧地說道。\n好你個葛東旭，繞了一大圈，除非了好幾次，原來是想為兄與青冥結為道侶，把三危山給拉入我天丹教啊！”楊銀厚聽到這裡，終於豁然明白過來。\n對，對，師兄果然是聰明人，一點就透，一點就透啊！”葛東旭連忙拍馬屁道。\n透你個頭啊！”楊銀厚忍不住白眼道，不過緊跟著在葛東旭還沒來得及開口好好開導勸說之際，楊銀厚已經撫著山羊鬍道：“不過這倒是一個好辦法，若是能把三危山拉入天丹教，一旦時機成熟，我們驟然出擊，必然能將西海龍宮他們殺個人仰馬翻，然後可以開始漸漸搶回一些地盤，逐步與他們進入拉鋸戰中。”\n沒錯，沒錯，就是這個計謀，就是這個計謀。這麼說，師兄是同意了？”葛東旭聞言不禁大為驚喜道。\n當然同意，這等人財兩得的主意，我為什麼不同意呢？”楊銀厚撫著山羊鬍，反問道。\n這個！”葛東旭被楊銀厚給問得一陣無語。\n人財兩得！想不到啊，真不想到啊，這等卑鄙齷齪的話連我都不好意思說出口，沒想到大師兄竟然說得那麼理所當然！'

# %%
"""
jieba
1. 分詞：我 / 喜歡 / 你
2. 抓重點詞：TF-IDF
"""
# Out:
# '\njieba\n1. 分詞：我 / 喜歡 / 你\n2. 抓重點詞：TF-IDF\n'

# %%
import jieba
from urllib.request import urlretrieve

with open("news.txt", "r", encoding="utf_8") as f:
    news = f.read()
    
url = "https://github.com/fxsjy/jieba/raw/master/extra_dict/dict.txt.big"
urlretrieve(url, "dict.txt.big")

jieba.set_dictionary("dict.txt.big")
jieba.load_userdict("health_dict.txt")

" ".join(jieba.cut(news))
# Out:
# Building prefix dict from C:\Users\User\PycharmProjects\P370\MLDemo_in_tibame\dict.txt.big ...
# Dumping model to file cache C:\Users\User\AppData\Local\Temp\jieba.uc63ab4df41b229f0f2dfaae92ef931f8.cache
# Loading model cost 1.562 seconds.
# Prefix dict has been built successfully.
# '台灣 連續 14 天 沒有 武漢肺炎 本土 確診 個案 ， 立委 關注 國內 疫情 是否 能 在 6 月底 告一段落 。 衛福部長 陳時中 表示 ， 有 這個 可能 ， 但 全球 疫情 仍會 持續 。 至於 秋冬 時期 疫情 是否 死灰復燃 ， 仍 需視 疫苗 研發 的 情形 。 \n \n 衛福部長 陳時中 上午 赴 立法院 財政 委員會 ， 專案 報告 「 嚴重 特殊 傳染性 肺炎 防治 及 紓 困 振興 特別 條例 施行 執行 情形 」 ， 並備 質詢 。 \n \n 由於 台灣 已經 連續 14 天 沒有 武漢肺炎 （ 2019 冠狀病毒 疾病 ,   COVID-19 ） 本土 確診 個案 ， 而 每天 增加 的 確診 案例 數字 低 ， 甚至 多次 出現 零例 的 情形 ， 不但 民眾 感到 安心 ， 也 讓 第一線 防疫 人員 提振 不少 士氣 。 \n \n 國民黨 立委 曾銘宗 質詢 時 關心 ， 台灣 連續 14 天 沒有 武漢肺炎 本土 確診 個案 ， 在 沒有 突發 的 情形 之下 ， 國內 疫情 是否 能 在 6 月底 告一段落 。 \n \n 陳時中 答詢 指出 ， 這 一個 時間 點 確實 是 有 可能 的 ， 但 他 也 補充 說明 ， 即便 國內 疫情 趨緩 ， 但是 全球 的 疫情 不太可能 在 6 月底 就 結束 。 \n \n 曾銘宗 進一步 詢問 ， 若 是 台灣 的 疫情 在 6 月底 順利 控制 住 ， 有沒有 可能 在 秋季 或 冬季 時 捲土重來 。 對於 這個 問題 ， 陳時中 坦言 ， 仍要 看 WHO 的 抗體 無用論 ， 在 科學 上 的 驗證 成果 。 \n \n 陳時中 指出 ， 如果 根據 科學 實證 ， 抗體 沒有 辦法 產生 一定 的 效果 ， 將會 對 疫苗 研發 產生 一定 的 影響 ， 如果 疫苗 無效 ， 那麼 疫情 在 秋冬 時 再來 一次 是 必然 的 情形 。 現在 大家 對於 疫苗 的 期待 度 確實 下降 ， 但是 這都 還是 要 科學 驗證 ， 此外 相關 的 藥物 研發 工作 也 持續 進行 。 \n \n 至於 是否 放寬 相關 的 防疫 規範 ， 陳時中 說明 ， 各 方面 措施 都 在 研議 中 ， 不管 是 3 階段 整備 方案 ， 或是 未來 情勢 有 改進 的話 ， 也 要 根據 相關 科學 證據 做 一些 放寬 的 準備 ， 這些 都 有 在 準備 中 。'

# %%
import jieba.analyse
jieba.analyse.extract_tags(news)
# Out:
# ['陳時中',
#  '疫情',
#  '沒有',
#  '台灣',
#  '確診',
#  '科學',
#  '連續',
#  '14',
#  '武漢肺炎',
#  '個案',
#  '國內',
#  '研發',
#  '相關',
#  '情形',
#  '疫苗',
#  '立委',
#  '月底',
#  '衛福部長',
#  '這個',
#  '持續']
